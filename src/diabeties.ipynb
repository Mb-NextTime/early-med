# %%
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import openml
from category_encoders import LeaveOneOutEncoder, CatBoostEncoder
import matplotlib.pyplot as plt

import pycaret
from pycaret.classification import ClassificationExperiment
from pycaret.datasets import get_data

from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import train_test_split

from ydata_profiling import ProfileReport

from utils import *
# Out:
#         <div>
#             <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#             <p>
#                 Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#             </p>
#         </div>

# %%
full_data = get_data('../data/diabetes/diabetes')
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
full_data.shape
# Out:
# (768, 9)

# %%
data, _ = train_test_split(full_data, train_size=200)

# %%
profile = ProfileReport(data, title="Pandas Profiling Report", minimal=True)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.13.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-03-20 19:56:44.560707&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 217 to 78
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               200 non-null    int64
#  1   Glucose                   200 non-null    int64
#  2   BloodPressure             200 non-null    int64
#  3   SkinThickness             200 non-null    int64
#  4   Insulin                   200 non-null    int64
#  5   BMI                       200 non-null    float64
#  6   DiabetesPedigreeFunction  200 non-null    float64
#  7   Age                       200 non-null    int64
#  8   Outcome                   200 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 15.6 KB

# %%
n_classes = data['Outcome'].unique().size

# %% [markdown]
# ---
# ### CatBoostEncoder

# %%
exp = ClassificationExperiment()
exp.setup(
    data,
    target='Outcome',
    session_id=42,
    preprocess=True,
    imputation_type='simple',
    normalize=True,
    normalize_method='zscore',
    encoding_method=CatBoostEncoder(),
    max_encoding_ohe=2,
    n_jobs=1
)
# Out:
# <style type="text/css">
# #T_3238e_row8_col1, #T_3238e_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3238e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3238e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3238e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3238e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3238e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3238e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3238e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3238e_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3238e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3238e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3238e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3238e_row3_col1" class="data row3 col1" >(200, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3238e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3238e_row4_col1" class="data row4 col1" >(200, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3238e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3238e_row5_col1" class="data row5 col1" >(140, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3238e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3238e_row6_col1" class="data row6 col1" >(60, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3238e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3238e_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3238e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3238e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3238e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3238e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3238e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3238e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3238e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3238e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3238e_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_3238e_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3238e_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_3238e_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3238e_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_3238e_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3238e_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_3238e_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3238e_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_3238e_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3238e_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_3238e_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3238e_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_3238e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3238e_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_3238e_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3238e_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_3238e_row20_col1" class="data row20 col1" >5388</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = exp.compare_models(exclude=['lda', 'dummy', 'nb', 'qda'], cross_validation=True)
# Out:
# <style type="text/css">
# #T_af6d4 th {
#   text-align: left;
# }
# #T_af6d4_row0_col0, #T_af6d4_row0_col2, #T_af6d4_row1_col0, #T_af6d4_row1_col1, #T_af6d4_row1_col3, #T_af6d4_row1_col4, #T_af6d4_row1_col5, #T_af6d4_row1_col6, #T_af6d4_row1_col7, #T_af6d4_row2_col0, #T_af6d4_row2_col1, #T_af6d4_row2_col2, #T_af6d4_row2_col3, #T_af6d4_row2_col4, #T_af6d4_row2_col5, #T_af6d4_row2_col6, #T_af6d4_row2_col7, #T_af6d4_row3_col0, #T_af6d4_row3_col1, #T_af6d4_row3_col2, #T_af6d4_row3_col3, #T_af6d4_row3_col4, #T_af6d4_row3_col5, #T_af6d4_row3_col6, #T_af6d4_row3_col7, #T_af6d4_row4_col0, #T_af6d4_row4_col1, #T_af6d4_row4_col2, #T_af6d4_row4_col3, #T_af6d4_row4_col4, #T_af6d4_row4_col5, #T_af6d4_row4_col6, #T_af6d4_row4_col7, #T_af6d4_row5_col0, #T_af6d4_row5_col1, #T_af6d4_row5_col2, #T_af6d4_row5_col3, #T_af6d4_row5_col4, #T_af6d4_row5_col5, #T_af6d4_row5_col6, #T_af6d4_row5_col7, #T_af6d4_row6_col0, #T_af6d4_row6_col1, #T_af6d4_row6_col2, #T_af6d4_row6_col3, #T_af6d4_row6_col4, #T_af6d4_row6_col5, #T_af6d4_row6_col6, #T_af6d4_row6_col7, #T_af6d4_row7_col0, #T_af6d4_row7_col1, #T_af6d4_row7_col2, #T_af6d4_row7_col3, #T_af6d4_row7_col4, #T_af6d4_row7_col5, #T_af6d4_row7_col6, #T_af6d4_row7_col7, #T_af6d4_row8_col0, #T_af6d4_row8_col1, #T_af6d4_row8_col2, #T_af6d4_row8_col3, #T_af6d4_row8_col4, #T_af6d4_row8_col5, #T_af6d4_row8_col6, #T_af6d4_row8_col7, #T_af6d4_row9_col0, #T_af6d4_row9_col1, #T_af6d4_row9_col2, #T_af6d4_row9_col3, #T_af6d4_row9_col4, #T_af6d4_row9_col5, #T_af6d4_row9_col6, #T_af6d4_row9_col7, #T_af6d4_row10_col0, #T_af6d4_row10_col1, #T_af6d4_row10_col2, #T_af6d4_row10_col3, #T_af6d4_row10_col4, #T_af6d4_row10_col5, #T_af6d4_row10_col6, #T_af6d4_row10_col7, #T_af6d4_row11_col0, #T_af6d4_row11_col1, #T_af6d4_row11_col2, #T_af6d4_row11_col3, #T_af6d4_row11_col4, #T_af6d4_row11_col5, #T_af6d4_row11_col6, #T_af6d4_row11_col7 {
#   text-align: left;
# }
# #T_af6d4_row0_col1, #T_af6d4_row0_col3, #T_af6d4_row0_col4, #T_af6d4_row0_col5, #T_af6d4_row0_col6, #T_af6d4_row0_col7, #T_af6d4_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_af6d4_row0_col8, #T_af6d4_row1_col8, #T_af6d4_row2_col8, #T_af6d4_row4_col8, #T_af6d4_row5_col8, #T_af6d4_row6_col8, #T_af6d4_row7_col8, #T_af6d4_row8_col8, #T_af6d4_row9_col8, #T_af6d4_row10_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_af6d4_row3_col8, #T_af6d4_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_af6d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af6d4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_af6d4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_af6d4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_af6d4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_af6d4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_af6d4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_af6d4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_af6d4_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_af6d4_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af6d4_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_af6d4_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_af6d4_row0_col1" class="data row0 col1" >0.7357</td>
#       <td id="T_af6d4_row0_col2" class="data row0 col2" >0.7510</td>
#       <td id="T_af6d4_row0_col3" class="data row0 col3" >0.6333</td>
#       <td id="T_af6d4_row0_col4" class="data row0 col4" >0.7401</td>
#       <td id="T_af6d4_row0_col5" class="data row0 col5" >0.6637</td>
#       <td id="T_af6d4_row0_col6" class="data row0 col6" >0.4518</td>
#       <td id="T_af6d4_row0_col7" class="data row0 col7" >0.4686</td>
#       <td id="T_af6d4_row0_col8" class="data row0 col8" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_af6d4_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_af6d4_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_af6d4_row1_col1" class="data row1 col1" >0.7143</td>
#       <td id="T_af6d4_row1_col2" class="data row1 col2" >0.7771</td>
#       <td id="T_af6d4_row1_col3" class="data row1 col3" >0.5833</td>
#       <td id="T_af6d4_row1_col4" class="data row1 col4" >0.6973</td>
#       <td id="T_af6d4_row1_col5" class="data row1 col5" >0.6211</td>
#       <td id="T_af6d4_row1_col6" class="data row1 col6" >0.4010</td>
#       <td id="T_af6d4_row1_col7" class="data row1 col7" >0.4131</td>
#       <td id="T_af6d4_row1_col8" class="data row1 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_af6d4_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_af6d4_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_af6d4_row2_col1" class="data row2 col1" >0.7071</td>
#       <td id="T_af6d4_row2_col2" class="data row2 col2" >0.7708</td>
#       <td id="T_af6d4_row2_col3" class="data row2 col3" >0.5833</td>
#       <td id="T_af6d4_row2_col4" class="data row2 col4" >0.6889</td>
#       <td id="T_af6d4_row2_col5" class="data row2 col5" >0.6189</td>
#       <td id="T_af6d4_row2_col6" class="data row2 col6" >0.3881</td>
#       <td id="T_af6d4_row2_col7" class="data row2 col7" >0.4003</td>
#       <td id="T_af6d4_row2_col8" class="data row2 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_af6d4_level0_row3" class="row_heading level0 row3" >svm</th>
#       <td id="T_af6d4_row3_col0" class="data row3 col0" >SVM - Linear Kernel</td>
#       <td id="T_af6d4_row3_col1" class="data row3 col1" >0.6786</td>
#       <td id="T_af6d4_row3_col2" class="data row3 col2" >0.7083</td>
#       <td id="T_af6d4_row3_col3" class="data row3 col3" >0.6000</td>
#       <td id="T_af6d4_row3_col4" class="data row3 col4" >0.6860</td>
#       <td id="T_af6d4_row3_col5" class="data row3 col5" >0.6059</td>
#       <td id="T_af6d4_row3_col6" class="data row3 col6" >0.3406</td>
#       <td id="T_af6d4_row3_col7" class="data row3 col7" >0.3711</td>
#       <td id="T_af6d4_row3_col8" class="data row3 col8" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_af6d4_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_af6d4_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_af6d4_row4_col1" class="data row4 col1" >0.6714</td>
#       <td id="T_af6d4_row4_col2" class="data row4 col2" >0.7042</td>
#       <td id="T_af6d4_row4_col3" class="data row4 col3" >0.5667</td>
#       <td id="T_af6d4_row4_col4" class="data row4 col4" >0.6483</td>
#       <td id="T_af6d4_row4_col5" class="data row4 col5" >0.5964</td>
#       <td id="T_af6d4_row4_col6" class="data row4 col6" >0.3225</td>
#       <td id="T_af6d4_row4_col7" class="data row4 col7" >0.3299</td>
#       <td id="T_af6d4_row4_col8" class="data row4 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_af6d4_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_af6d4_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_af6d4_row5_col1" class="data row5 col1" >0.6714</td>
#       <td id="T_af6d4_row5_col2" class="data row5 col2" >0.7375</td>
#       <td id="T_af6d4_row5_col3" class="data row5 col3" >0.5333</td>
#       <td id="T_af6d4_row5_col4" class="data row5 col4" >0.6634</td>
#       <td id="T_af6d4_row5_col5" class="data row5 col5" >0.5756</td>
#       <td id="T_af6d4_row5_col6" class="data row5 col6" >0.3157</td>
#       <td id="T_af6d4_row5_col7" class="data row5 col7" >0.3313</td>
#       <td id="T_af6d4_row5_col8" class="data row5 col8" >0.4660</td>
#     </tr>
#     <tr>
#       <th id="T_af6d4_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_af6d4_row6_col0" class="data row6 col0" >Random Forest Classifier</td>
#       <td id="T_af6d4_row6_col1" class="data row6 col1" >0.6571</td>
#       <td id="T_af6d4_row6_col2" class="data row6 col2" >0.7323</td>
#       <td id

# %%
best = exp.create_model('et')
# Out:
# <style type="text/css">
# #T_07d67_row10_col0, #T_07d67_row10_col1, #T_07d67_row10_col2, #T_07d67_row10_col3, #T_07d67_row10_col4, #T_07d67_row10_col5, #T_07d67_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_07d67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07d67_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_07d67_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_07d67_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_07d67_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_07d67_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_07d67_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_07d67_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07d67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07d67_row0_col0" class="data row0 col0" >0.7857</td>
#       <td id="T_07d67_row0_col1" class="data row0 col1" >0.9062</td>
#       <td id="T_07d67_row0_col2" class="data row0 col2" >0.8333</td>
#       <td id="T_07d67_row0_col3" class="data row0 col3" >0.7143</td>
#       <td id="T_07d67_row0_col4" class="data row0 col4" >0.7692</td>
#       <td id="T_07d67_row0_col5" class="data row0 col5" >0.5714</td>
#       <td id="T_07d67_row0_col6" class="data row0 col6" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07d67_row1_col0" class="data row1 col0" >0.7143</td>
#       <td id="T_07d67_row1_col1" class="data row1 col1" >0.7500</td>
#       <td id="T_07d67_row1_col2" class="data row1 col2" >0.8333</td>
#       <td id="T_07d67_row1_col3" class="data row1 col3" >0.6250</td>
#       <td id="T_07d67_row1_col4" class="data row1 col4" >0.7143</td>
#       <td id="T_07d67_row1_col5" class="data row1 col5" >0.4400</td>
#       <td id="T_07d67_row1_col6" class="data row1 col6" >0.4583</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07d67_row2_col0" class="data row2 col0" >0.7143</td>
#       <td id="T_07d67_row2_col1" class="data row2 col1" >0.6354</td>
#       <td id="T_07d67_row2_col2" class="data row2 col2" >0.6667</td>
#       <td id="T_07d67_row2_col3" class="data row2 col3" >0.6667</td>
#       <td id="T_07d67_row2_col4" class="data row2 col4" >0.6667</td>
#       <td id="T_07d67_row2_col5" class="data row2 col5" >0.4167</td>
#       <td id="T_07d67_row2_col6" class="data row2 col6" >0.4167</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07d67_row3_col0" class="data row3 col0" >0.6429</td>
#       <td id="T_07d67_row3_col1" class="data row3 col1" >0.3542</td>
#       <td id="T_07d67_row3_col2" class="data row3 col2" >0.3333</td>
#       <td id="T_07d67_row3_col3" class="data row3 col3" >0.6667</td>
#       <td id="T_07d67_row3_col4" class="data row3 col4" >0.4444</td>
#       <td id="T_07d67_row3_col5" class="data row3 col5" >0.2222</td>
#       <td id="T_07d67_row3_col6" class="data row3 col6" >0.2513</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07d67_row4_col0" class="data row4 col0" >0.6429</td>
#       <td id="T_07d67_row4_col1" class="data row4 col1" >0.6458</td>
#       <td id="T_07d67_row4_col2" class="data row4 col2" >0.3333</td>
#       <td id="T_07d67_row4_col3" class="data row4 col3" >0.6667</td>
#       <td id="T_07d67_row4_col4" class="data row4 col4" >0.4444</td>
#       <td id="T_07d67_row4_col5" class="data row4 col5" >0.2222</td>
#       <td id="T_07d67_row4_col6" class="data row4 col6" >0.2513</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07d67_row5_col0" class="data row5 col0" >0.9286</td>
#       <td id="T_07d67_row5_col1" class="data row5 col1" >0.9792</td>
#       <td id="T_07d67_row5_col2" class="data row5 col2" >0.8333</td>
#       <td id="T_07d67_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_07d67_row5_col4" class="data row5 col4" >0.9091</td>
#       <td id="T_07d67_row5_col5" class="data row5 col5" >0.8511</td>
#       <td id="T_07d67_row5_col6" class="data row5 col6" >0.8607</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07d67_row6_col0" class="data row6 col0" >0.7857</td>
#       <td id="T_07d67_row6_col1" class="data row6 col1" >0.9062</td>
#       <td id="T_07d67_row6_col2" class="data row6 col2" >0.6667</td>
#       <td id="T_07d67_row6_col3" class="data row6 col3" >0.8000</td>
#       <td id="T_07d67_row6_col4" class="data row6 col4" >0.7273</td>
#       <td id="T_07d67_row6_col5" class="data row6 col5" >0.5532</td>
#       <td id="T_07d67_row6_col6" class="data row6 col6" >0.5594</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_07d67_row7_col0" class="data row7 col0" >0.5000</td>
#       <td id="T_07d67_row7_col1" class="data row7 col1" >0.6146</td>
#       <td id="T_07d67_row7_col2" class="data row7 col2" >0.5000</td>
#       <td id="T_07d67_row7_col3" class="data row7 col3" >0.4286</td>
#       <td id="T_07d67_row7_col4" class="data row7 col4" >0.4615</td>
#       <td id="T_07d67_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_07d67_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_07d67_row8_col0" class="data row8 col0" >0.7857</td>
#       <td id="T_07d67_row8_col1" class="data row8 col1" >0.8333</td>
#       <td id="T_07d67_row8_col2" class="data row8 col2" >0.5000</td>
#       <td id="T_07d67_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_07d67_row8_col4" class="data row8 col4" >0.6667</td>
#       <td id="T_07d67_row8_col5" class="data row8 col5" >0.5333</td>
#       <td id="T_07d67_row8_col6" class="data row8 col6" >0.6030</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_07d67_row9_col0" class="data row9 col0" >0.8571</td>
#       <td id="T_07d67_row9_col1" class="data row9 col1" >0.8854</td>
#       <td id="T_07d67_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_07d67_row9_col3" class="data row9 col3" >0.8333</td>
#       <td id="T_07d67_row9_col4" class="data row9 col4" >0.8333</td>
#       <td id="T_07d67_row9_col5" class="data row9 col5" >0.7083</td>
#       <td id="T_07d67_row9_col6" class="data row9 col6" >0.7083</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_07d67_row10_col0" class="data row10 col0" >0.7357</td>
#       <td id="T_07d67_row10_col1" class="data row10 col1" >0.7510</td>
#       <td id="T_07d67_row10_col2" class="data row10 col2" >0.6333</td>
#       <td id="T_07d67_row10_col3" class="data row10 col3" >0.7401</td>
#       <td id="T_07d67_row10_col4" class="data row10 col4" >0.6637</td>
#       <td id="T_07d67_row10_col5" class="data row10 col5" >0.4518</td>
#       <td id="T_07d67_row10_col6" class="data row10 col6" >0.4686</td>
#     </tr>
#     <tr>
#       <th id="T_07d67_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_07d67_row11_col0" class="data row11 col0" >0.1154</td>
#       <td id="T_07d67_row11_col1" class="data row11 col1" >0.1804</td>
#       <td id="T_07d67_row11_col2" class="data row11 col2" >0.1944</td>
#       <td id="T_07d67_row11_col3" class="data row11 col3" >0.1657</td>
#       <td id="T_07d67_row11_col4

# %%
exp.plot_model(best, plot='learning')

# %%
fc = FeatureCurve(best, exp.X_train_transformed, exp.y_train_transformed, features_order=exp.X_train_transformed.columns)
fc.fit(exp.X_train_transformed, exp.y_train_transformed)

# %%
fc = FeatureCurve(best, exp.X_train_transformed, exp.y_train_transformed)
fc.fit(exp.X_train_transformed, exp.y_train_transformed)

# %%
# %%time
flc = FeatureLearningCurve(best, exp.X_train_transformed, exp.y_train_transformed, cv=5,
                           features_order=fc.features_order_,
                           scoring=balanced_accuracy_score
)
flc.fit(exp.X_train_transformed, exp.y_train_transformed, exp.X_test_transformed, exp.y_test_transformed)
# Out:
# CPU times: user 10.3 s, sys: 19.6 ms, total: 10.4 s
# Wall time: 10.4 s

# %% [markdown]
# ---
# ### TabEBM with CatBoostEncoder

# %%
from tabebm.TabEBM import TabEBM

# %%
tabebm = TabEBM(plotting=False)
augmented_data = tabebm.generate(exp.X_train_transformed.values, exp.y_train_transformed.values, num_samples=500//n_classes)

# %%
X_syn = np.concatenate(list(augmented_data.values()))
y_syn = np.concatenate([np.full(len(augmented_data[f"class_{i}"]), i) for i in range(len(augmented_data.keys()))])
X_train_augmented = np.concatenate([exp.X_train_transformed, X_syn])
y_train_augmented = np.concatenate([exp.y_train_transformed, y_syn])

# %%
best.fit(exp.X_train_transformed, exp.y_train_transformed)
balanced_accuracy_score(best.predict(exp.X_test_transformed), exp.y_test_transformed)
# Out:
# 0.7479435957696827

# %%
best.fit(X_train_augmented, y_train_augmented)
balanced_accuracy_score(best.predict(exp.X_test_transformed), exp.y_test_transformed)
# Out:
# 0.7285067873303167

# %% [markdown]
# ---
# ### Full data experiement

# %%
exp_full = ClassificationExperiment()
exp_full.setup(
    full_data,
    target='Outcome',
    session_id=42,
    preprocess=True,
    imputation_type='simple',
    normalize=True,
    normalize_method='zscore',
    encoding_method=CatBoostEncoder(),
    max_encoding_ohe=2,
    n_jobs=1
)
# Out:
# <style type="text/css">
# #T_a06eb_row8_col1, #T_a06eb_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a06eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a06eb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a06eb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a06eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a06eb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a06eb_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a06eb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a06eb_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a06eb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a06eb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a06eb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a06eb_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a06eb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a06eb_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a06eb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a06eb_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a06eb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a06eb_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a06eb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a06eb_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a06eb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a06eb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a06eb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a06eb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a06eb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a06eb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a06eb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a06eb_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a06eb_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_a06eb_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a06eb_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_a06eb_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a06eb_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_a06eb_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a06eb_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_a06eb_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a06eb_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_a06eb_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a06eb_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_a06eb_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a06eb_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_a06eb_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a06eb_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_a06eb_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a06eb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a06eb_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_a06eb_row20_col1" class="data row20 col1" >0919</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_full = exp_full.compare_models(exclude=['lda', 'dummy', 'nb', 'qda'], cross_validation=True)
# Out:
# <style type="text/css">
# #T_49dcd th {
#   text-align: left;
# }
# #T_49dcd_row0_col0, #T_49dcd_row0_col2, #T_49dcd_row1_col0, #T_49dcd_row1_col1, #T_49dcd_row1_col3, #T_49dcd_row1_col4, #T_49dcd_row1_col5, #T_49dcd_row1_col6, #T_49dcd_row1_col7, #T_49dcd_row2_col0, #T_49dcd_row2_col1, #T_49dcd_row2_col2, #T_49dcd_row2_col3, #T_49dcd_row2_col4, #T_49dcd_row2_col5, #T_49dcd_row2_col6, #T_49dcd_row2_col7, #T_49dcd_row3_col0, #T_49dcd_row3_col1, #T_49dcd_row3_col2, #T_49dcd_row3_col3, #T_49dcd_row3_col4, #T_49dcd_row3_col5, #T_49dcd_row3_col6, #T_49dcd_row3_col7, #T_49dcd_row4_col0, #T_49dcd_row4_col1, #T_49dcd_row4_col2, #T_49dcd_row4_col3, #T_49dcd_row4_col4, #T_49dcd_row4_col5, #T_49dcd_row4_col6, #T_49dcd_row4_col7, #T_49dcd_row5_col0, #T_49dcd_row5_col1, #T_49dcd_row5_col2, #T_49dcd_row5_col3, #T_49dcd_row5_col4, #T_49dcd_row5_col5, #T_49dcd_row5_col6, #T_49dcd_row5_col7, #T_49dcd_row6_col0, #T_49dcd_row6_col1, #T_49dcd_row6_col2, #T_49dcd_row6_col3, #T_49dcd_row6_col4, #T_49dcd_row6_col5, #T_49dcd_row6_col6, #T_49dcd_row6_col7, #T_49dcd_row7_col0, #T_49dcd_row7_col1, #T_49dcd_row7_col2, #T_49dcd_row7_col3, #T_49dcd_row7_col4, #T_49dcd_row7_col5, #T_49dcd_row7_col6, #T_49dcd_row7_col7, #T_49dcd_row8_col0, #T_49dcd_row8_col1, #T_49dcd_row8_col2, #T_49dcd_row8_col3, #T_49dcd_row8_col4, #T_49dcd_row8_col5, #T_49dcd_row8_col6, #T_49dcd_row8_col7, #T_49dcd_row9_col0, #T_49dcd_row9_col1, #T_49dcd_row9_col2, #T_49dcd_row9_col3, #T_49dcd_row9_col4, #T_49dcd_row9_col5, #T_49dcd_row9_col6, #T_49dcd_row9_col7, #T_49dcd_row10_col0, #T_49dcd_row10_col1, #T_49dcd_row10_col2, #T_49dcd_row10_col3, #T_49dcd_row10_col4, #T_49dcd_row10_col5, #T_49dcd_row10_col6, #T_49dcd_row10_col7, #T_49dcd_row11_col0, #T_49dcd_row11_col1, #T_49dcd_row11_col2, #T_49dcd_row11_col3, #T_49dcd_row11_col4, #T_49dcd_row11_col5, #T_49dcd_row11_col6, #T_49dcd_row11_col7 {
#   text-align: left;
# }
# #T_49dcd_row0_col1, #T_49dcd_row0_col3, #T_49dcd_row0_col4, #T_49dcd_row0_col5, #T_49dcd_row0_col6, #T_49dcd_row0_col7, #T_49dcd_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_49dcd_row0_col8, #T_49dcd_row2_col8, #T_49dcd_row3_col8, #T_49dcd_row4_col8, #T_49dcd_row5_col8, #T_49dcd_row6_col8, #T_49dcd_row7_col8, #T_49dcd_row8_col8, #T_49dcd_row9_col8, #T_49dcd_row10_col8, #T_49dcd_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_49dcd_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_49dcd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49dcd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_49dcd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_49dcd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_49dcd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_49dcd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_49dcd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_49dcd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_49dcd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_49dcd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49dcd_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_49dcd_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_49dcd_row0_col1" class="data row0 col1" >0.7784</td>
#       <td id="T_49dcd_row0_col2" class="data row0 col2" >0.8291</td>
#       <td id="T_49dcd_row0_col3" class="data row0 col3" >0.5819</td>
#       <td id="T_49dcd_row0_col4" class="data row0 col4" >0.7369</td>
#       <td id="T_49dcd_row0_col5" class="data row0 col5" >0.6397</td>
#       <td id="T_49dcd_row0_col6" class="data row0 col6" >0.4851</td>
#       <td id="T_49dcd_row0_col7" class="data row0 col7" >0.4994</td>
#       <td id="T_49dcd_row0_col8" class="data row0 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_49dcd_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_49dcd_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_49dcd_row1_col1" class="data row1 col1" >0.7747</td>
#       <td id="T_49dcd_row1_col2" class="data row1 col2" >0.8304</td>
#       <td id="T_49dcd_row1_col3" class="data row1 col3" >0.5661</td>
#       <td id="T_49dcd_row1_col4" class="data row1 col4" >0.7344</td>
#       <td id="T_49dcd_row1_col5" class="data row1 col5" >0.6297</td>
#       <td id="T_49dcd_row1_col6" class="data row1 col6" >0.4740</td>
#       <td id="T_49dcd_row1_col7" class="data row1 col7" >0.4883</td>
#       <td id="T_49dcd_row1_col8" class="data row1 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_49dcd_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_49dcd_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_49dcd_row2_col1" class="data row2 col1" >0.7579</td>
#       <td id="T_49dcd_row2_col2" class="data row2 col2" >0.8204</td>
#       <td id="T_49dcd_row2_col3" class="data row2 col3" >0.5664</td>
#       <td id="T_49dcd_row2_col4" class="data row2 col4" >0.6888</td>
#       <td id="T_49dcd_row2_col5" class="data row2 col5" >0.6118</td>
#       <td id="T_49dcd_row2_col6" class="data row2 col6" >0.4410</td>
#       <td id="T_49dcd_row2_col7" class="data row2 col7" >0.4526</td>
#       <td id="T_49dcd_row2_col8" class="data row2 col8" >0.7500</td>
#     </tr>
#     <tr>
#       <th id="T_49dcd_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_49dcd_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_49dcd_row3_col1" class="data row3 col1" >0.7524</td>
#       <td id="T_49dcd_row3_col2" class="data row3 col2" >0.8100</td>
#       <td id="T_49dcd_row3_col3" class="data row3 col3" >0.5605</td>
#       <td id="T_49dcd_row3_col4" class="data row3 col4" >0.6824</td>
#       <td id="T_49dcd_row3_col5" class="data row3 col5" >0.5995</td>
#       <td id="T_49dcd_row3_col6" class="data row3 col6" >0.4275</td>
#       <td id="T_49dcd_row3_col7" class="data row3 col7" >0.4427</td>
#       <td id="T_49dcd_row3_col8" class="data row3 col8" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_49dcd_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_49dcd_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_49dcd_row4_col1" class="data row4 col1" >0.7449</td>
#       <td id="T_49dcd_row4_col2" class="data row4 col2" >0.8169</td>
#       <td id="T_49dcd_row4_col3" class="data row4 col3" >0.5398</td>
#       <td id="T_49dcd_row4_col4" class="data row4 col4" >0.6773</td>
#       <td id="T_49dcd_row4_col5" class="data row4 col5" >0.5874</td>
#       <td id="T_49dcd_row4_col6" class="data row4 col6" >0.4096</td>
#       <td id="T_49dcd_row4_col7" class="data row4 col7" >0.4239</td>
#       <td id="T_49dcd_row4_col8" class="data row4 col8" >0.1110</td>
#     </tr>
#     <tr>
#       <th id="T_49dcd_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_49dcd_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_49dcd_row5_col1" class="data row5 col1" >0.7412</td>
#       <td id="T_49dcd_row5_col2" class="data row5 col2" >0.8111</td>
#       <td id="T_49dcd_row5_col3" class="data row5 col3" >0.5453</td>
#       <td id="T_49dcd_row5_col4" class="data row5 col4" >0.6626</td>
#       <td id="T_49dcd_row5_col5" class="data row5 col5" >0.5903</td>
#       <td id="T_49dcd_row5_col6" class="data row5 col6" >0.4057</td>
#       <td id="T_49dcd_row5_col7" class="data row5 col7" >0.4150</td>
#       <td id="T_49dcd_row5_col8" class="data row5 col8" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_49dcd_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_49dcd_row6_col0" class="data row6 col0" >Ada Boost Classifier</td>
#       <td id="T_49dcd_row6_col1" class="data row6 col1" >0.7336</td>
#       <td id="T_49dcd_row6_col2" class="data row6 col2" >0.7854</td>
#       <td id

# %% [markdown]
# ---
# Let's test the hypotise that only some features are enough for an accurate classifier

# %%
exp_full = ClassificationExperiment()
exp_full.setup(
    full_data[['Glucose', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']],
    target='Outcome',
    session_id=42,
    preprocess=True,
    imputation_type='simple',
    normalize=True,
    normalize_method='zscore',
    encoding_method=CatBoostEncoder(),
    max_encoding_ohe=2,
    n_jobs=1
)
# Out:
# <style type="text/css">
# #T_f9513_row8_col1, #T_f9513_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f9513">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9513_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f9513_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9513_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9513_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f9513_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9513_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f9513_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9513_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f9513_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9513_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f9513_row3_col1" class="data row3 col1" >(768, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9513_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f9513_row4_col1" class="data row4 col1" >(768, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9513_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f9513_row5_col1" class="data row5 col1" >(537, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f9513_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f9513_row6_col1" class="data row6 col1" >(231, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f9513_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f9513_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f9513_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f9513_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f9513_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f9513_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f9513_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f9513_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f9513_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f9513_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f9513_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_f9513_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f9513_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_f9513_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f9513_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_f9513_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f9513_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_f9513_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f9513_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_f9513_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f9513_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_f9513_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f9513_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_f9513_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f9513_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_f9513_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f9513_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f9513_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_f9513_row20_col1" class="data row20 col1" >a142</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_full = exp_full.compare_models(exclude=['lda', 'dummy', 'nb', 'qda'], cross_validation=True)
# Out:
# <style type="text/css">
# #T_9f9a7 th {
#   text-align: left;
# }
# #T_9f9a7_row0_col0, #T_9f9a7_row1_col0, #T_9f9a7_row1_col1, #T_9f9a7_row1_col2, #T_9f9a7_row1_col3, #T_9f9a7_row1_col4, #T_9f9a7_row1_col5, #T_9f9a7_row1_col6, #T_9f9a7_row1_col7, #T_9f9a7_row2_col0, #T_9f9a7_row2_col1, #T_9f9a7_row2_col2, #T_9f9a7_row2_col3, #T_9f9a7_row2_col4, #T_9f9a7_row2_col5, #T_9f9a7_row2_col6, #T_9f9a7_row2_col7, #T_9f9a7_row3_col0, #T_9f9a7_row3_col1, #T_9f9a7_row3_col2, #T_9f9a7_row3_col3, #T_9f9a7_row3_col4, #T_9f9a7_row3_col5, #T_9f9a7_row3_col6, #T_9f9a7_row3_col7, #T_9f9a7_row4_col0, #T_9f9a7_row4_col1, #T_9f9a7_row4_col2, #T_9f9a7_row4_col3, #T_9f9a7_row4_col4, #T_9f9a7_row4_col5, #T_9f9a7_row4_col6, #T_9f9a7_row4_col7, #T_9f9a7_row5_col0, #T_9f9a7_row5_col1, #T_9f9a7_row5_col2, #T_9f9a7_row5_col3, #T_9f9a7_row5_col4, #T_9f9a7_row5_col5, #T_9f9a7_row5_col6, #T_9f9a7_row5_col7, #T_9f9a7_row6_col0, #T_9f9a7_row6_col1, #T_9f9a7_row6_col2, #T_9f9a7_row6_col3, #T_9f9a7_row6_col4, #T_9f9a7_row6_col5, #T_9f9a7_row6_col6, #T_9f9a7_row6_col7, #T_9f9a7_row7_col0, #T_9f9a7_row7_col1, #T_9f9a7_row7_col2, #T_9f9a7_row7_col3, #T_9f9a7_row7_col4, #T_9f9a7_row7_col5, #T_9f9a7_row7_col6, #T_9f9a7_row7_col7, #T_9f9a7_row8_col0, #T_9f9a7_row8_col1, #T_9f9a7_row8_col2, #T_9f9a7_row8_col3, #T_9f9a7_row8_col4, #T_9f9a7_row8_col5, #T_9f9a7_row8_col6, #T_9f9a7_row8_col7, #T_9f9a7_row9_col0, #T_9f9a7_row9_col1, #T_9f9a7_row9_col2, #T_9f9a7_row9_col3, #T_9f9a7_row9_col4, #T_9f9a7_row9_col5, #T_9f9a7_row9_col6, #T_9f9a7_row9_col7, #T_9f9a7_row10_col0, #T_9f9a7_row10_col1, #T_9f9a7_row10_col2, #T_9f9a7_row10_col3, #T_9f9a7_row10_col4, #T_9f9a7_row10_col5, #T_9f9a7_row10_col6, #T_9f9a7_row10_col7, #T_9f9a7_row11_col0, #T_9f9a7_row11_col1, #T_9f9a7_row11_col2, #T_9f9a7_row11_col3, #T_9f9a7_row11_col4, #T_9f9a7_row11_col5, #T_9f9a7_row11_col6, #T_9f9a7_row11_col7 {
#   text-align: left;
# }
# #T_9f9a7_row0_col1, #T_9f9a7_row0_col2, #T_9f9a7_row0_col3, #T_9f9a7_row0_col4, #T_9f9a7_row0_col5, #T_9f9a7_row0_col6, #T_9f9a7_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9f9a7_row0_col8, #T_9f9a7_row1_col8, #T_9f9a7_row10_col8, #T_9f9a7_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_9f9a7_row2_col8, #T_9f9a7_row3_col8, #T_9f9a7_row4_col8, #T_9f9a7_row5_col8, #T_9f9a7_row6_col8, #T_9f9a7_row7_col8, #T_9f9a7_row8_col8, #T_9f9a7_row9_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9f9a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f9a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9f9a7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9f9a7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9f9a7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9f9a7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9f9a7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9f9a7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9f9a7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9f9a7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f9a7_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_9f9a7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_9f9a7_row0_col1" class="data row0 col1" >0.7820</td>
#       <td id="T_9f9a7_row0_col2" class="data row0 col2" >0.8234</td>
#       <td id="T_9f9a7_row0_col3" class="data row0 col3" >0.5816</td>
#       <td id="T_9f9a7_row0_col4" class="data row0 col4" >0.7392</td>
#       <td id="T_9f9a7_row0_col5" class="data row0 col5" >0.6425</td>
#       <td id="T_9f9a7_row0_col6" class="data row0 col6" >0.4911</td>
#       <td id="T_9f9a7_row0_col7" class="data row0 col7" >0.5039</td>
#       <td id="T_9f9a7_row0_col8" class="data row0 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_9f9a7_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_9f9a7_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_9f9a7_row1_col1" class="data row1 col1" >0.7764</td>
#       <td id="T_9f9a7_row1_col2" class="data row1 col2" >0.8221</td>
#       <td id="T_9f9a7_row1_col3" class="data row1 col3" >0.5605</td>
#       <td id="T_9f9a7_row1_col4" class="data row1 col4" >0.7364</td>
#       <td id="T_9f9a7_row1_col5" class="data row1 col5" >0.6272</td>
#       <td id="T_9f9a7_row1_col6" class="data row1 col6" >0.4745</td>
#       <td id="T_9f9a7_row1_col7" class="data row1 col7" >0.4893</td>
#       <td id="T_9f9a7_row1_col8" class="data row1 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_9f9a7_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_9f9a7_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_9f9a7_row2_col1" class="data row2 col1" >0.7596</td>
#       <td id="T_9f9a7_row2_col2" class="data row2 col2" >0.7953</td>
#       <td id="T_9f9a7_row2_col3" class="data row2 col3" >0.5658</td>
#       <td id="T_9f9a7_row2_col4" class="data row2 col4" >0.6901</td>
#       <td id="T_9f9a7_row2_col5" class="data row2 col5" >0.6126</td>
#       <td id="T_9f9a7_row2_col6" class="data row2 col6" >0.4435</td>
#       <td id="T_9f9a7_row2_col7" class="data row2 col7" >0.4546</td>
#       <td id="T_9f9a7_row2_col8" class="data row2 col8" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_9f9a7_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_9f9a7_row3_col0" class="data row3 col0" >CatBoost Classifier</td>
#       <td id="T_9f9a7_row3_col1" class="data row3 col1" >0.7522</td>
#       <td id="T_9f9a7_row3_col2" class="data row3 col2" >0.8220</td>
#       <td id="T_9f9a7_row3_col3" class="data row3 col3" >0.5754</td>
#       <td id="T_9f9a7_row3_col4" class="data row3 col4" >0.6678</td>
#       <td id="T_9f9a7_row3_col5" class="data row3 col5" >0.6058</td>
#       <td id="T_9f9a7_row3_col6" class="data row3 col6" >0.4306</td>
#       <td id="T_9f9a7_row3_col7" class="data row3 col7" >0.4416</td>
#       <td id="T_9f9a7_row3_col8" class="data row3 col8" >0.5870</td>
#     </tr>
#     <tr>
#       <th id="T_9f9a7_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_9f9a7_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_9f9a7_row4_col1" class="data row4 col1" >0.7467</td>
#       <td id="T_9f9a7_row4_col2" class="data row4 col2" >0.8104</td>
#       <td id="T_9f9a7_row4_col3" class="data row4 col3" >0.5497</td>
#       <td id="T_9f9a7_row4_col4" class="data row4 col4" >0.6800</td>
#       <td id="T_9f9a7_row4_col5" class="data row4 col5" >0.5930</td>
#       <td id="T_9f9a7_row4_col6" class="data row4 col6" >0.4155</td>
#       <td id="T_9f9a7_row4_col7" class="data row4 col7" >0.4299</td>
#       <td id="T_9f9a7_row4_col8" class="data row4 col8" >0.0850</td>
#     </tr>
#     <tr>
#       <th id="T_9f9a7_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_9f9a7_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_9f9a7_row5_col1" class="data row5 col1" >0.7448</td>
#       <td id="T_9f9a7_row5_col2" class="data row5 col2" >0.8010</td>
#       <td id="T_9f9a7_row5_col3" class="data row5 col3" >0.5705</td>
#       <td id="T_9f9a7_row5_col4" class="data row5 col4" >0.6538</td>
#       <td id="T_9f9a7_row5_col5" class="data row5 col5" >0.5987</td>
#       <td id="T_9f9a7_row5_col6" class="data row5 col6" >0.4161</td>
#       <td id="T_9f9a7_row5_col7" class="data row5 col7" >0.4250</td>
#       <td id="T_9f9a7_row5_col8" class="data row5 col8" >0.1050</td>
#     </tr>
#     <tr>
#       <th id="T_9f9a7_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_9f9a7_row6_col0" class="data row6 col0" >K Neighbors Classifier</td>
#       <td id="T_9f9a7_row6_col1" class="data row6 col1" >0.7356</td>
#       <td id="T_9f9a7_row6_col2" class="data row6 col2" >0.7730</td>
#       <td i
